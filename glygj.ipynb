# %%
from itertools import combinations


class Glygj(object):
    """
    目的是找出能推進至最多關卡的最佳`門客組合`
    To pass stages as much as possible, we try to find the best `guest combinations` with the minimum waste.
    """
    targets = [200110, 450310, 800680, 1251300, 1801800,
               2452500, 3203900, 4055700, 5008000, 6616990,
               8426000, 11238000, 20000000, 50000000, 100000000,
               200000000, 600000000, 700000000]

    guests = {'高漸離': 1133600000,
              '高長恭': 259800000,
              '李廣': 73942950,
              '魏忠賢': 63488372,
              '魏徵': 58985817,
              '干將': 25136545,
              '蕭劍': 16094176,
              '蘇秦': 12039126,
              '李白': 12038944,
              '陳近南': 11069727,
              'Liang': 10638335,
              '洪承疇': 10073098,
              '年羹堯': 10067898,
              '林則徐': 10066898,
              '納蘭明珠': 10040902,
              '東方朔': 10040499,
              '張衡': 7029336,
              '范文程': 7028349,
              '胡雪巖': 7028208,
              '華安': 6035999,
              '索尼': 6025145,
              'Fan': 5407408,
              '蘇軾': 4514877,
              '劉墉': 4514367,
              '歐陽修': 2363172,
              '曹雪芹': 2102748,
              '紀昀': 1476828,
              '鄭板橋': 1181527,
              '周培公': 1181520,
              '李衛': 1181513,
              '張廷玉': 886091}

    nb_guests = len(guests)
    nb_targets = len(guests)

    def __init__(self):
        self.verbose = False
        self.init_n = 1
        self.breakpoint = 6

    def run(self):
        """
        TODO: Instead of the Brute-force method, ML methods may be more efficient.
        """
        def f1(targetPower):
            scoreboard = []
            for n in range(init_n, len(guests) + 1):
                combs = combinations(guests.keys(), n)
                for comb_names in combs:
                    comb_powers = sum([guests[name] for name in comb_names])
                    waste = comb_powers - targetPower
                    if verbose:
                        print(
                            indents + f"{comb_names}, {comb_powers}, {waste}")
                    if waste >= 0:
                        scoreboard.append((comb_names, comb_powers, waste))
                if n >= breakpoint:
                    break

            if not scoreboard:
                return None

            # check scoreboard
            comb = min(scoreboard, key=lambda x: x[2])
            return comb

        init_n = self.init_n
        guests = self.guests
        targets = self.targets
        breakpoint = self.breakpoint
        verbose = self.verbose

        for targetPower in targets:
            if len(guests) == 0:
                print('done')
                break
            print(f"targetPower: {targetPower}")
            comb = f1(targetPower)
            if comb is None:
                print('done')
                break
            indents = " " * 5
            print(indents + f"lowest_waste: {comb}")
            comb_names = comb[0]
            for comb_name in comb_names:
                guests.pop(comb_name)
            print(indents + f"remain: {len(guests)}")

        print('\n')
        print(f"remain: {guests}")
        print(f"remainPower: {sum([v for k, v in guests.items()])}")


if __name__ == '__main__':
    g = Glygj()
    g.run()
# Out:
# targetPower: 200110
#      lowest_waste: (('張廷玉',), 886091, 685981)
#      remain: 30
# targetPower: 450310
#      lowest_waste: (('李衛',), 1181513, 731203)
#      remain: 29
# targetPower: 800680
#      lowest_waste: (('周培公',), 1181520, 380840)
#      remain: 28
# targetPower: 1251300
#      lowest_waste: (('紀昀',), 1476828, 225528)
#      remain: 27
# targetPower: 1801800
#      lowest_waste: (('曹雪芹',), 2102748, 300948)
#      remain: 26
# targetPower: 2452500
#      lowest_waste: (('歐陽修', '鄭板橋'), 3544699, 1092199)
#      remain: 24
# targetPower: 3203900
#      lowest_waste: (('劉墉',), 4514367, 1310467)
#      remain: 23
# targetPower: 4055700
#      lowest_waste: (('蘇軾',), 4514877, 459177)
#      remain: 22
# targetPower: 5008000
#      lowest_waste: (('Fan',), 5407408, 399408)
#      remain: 21
# targetPower: 6616990
#      lowest_waste: (('胡雪巖',), 7028208, 411218)
#      remain: 20
# targetPower: 8426000
#      lowest_waste: (('東方朔',), 10040499, 1614499)
#      remain: 19
# targetPower: 11238000
#      lowest_waste: (('李白',), 12038944, 800944)
#      remain: 18
# targetPower: 20000000
#      lowest_waste: (('張衡', '范文程', '索尼'), 20082830, 82830)
#      remain: 15
# targetPower: 50000000
#      lowest_waste: (('Liang', '洪承疇', '年羹堯', '林則徐', '納蘭明珠'), 50887131, 887131)
#      remain: 10
# targetPower: 100000000
#      lowest_waste: (('魏徵', '干將', '蕭劍'), 100216538, 216538)
#      remain: 7
# targetPower: 200000000
#      lowest_waste: (('高長恭',), 259800000, 59800000)
#      remain: 6
# targetPower: 600000000
#      lowest_waste: (('高漸離',), 1133600000, 533600000)
#      remain: 5
# targetPower: 700000000
# done
#
#
# remain: {'李廣': 73942950, '魏忠賢': 63488372, '蘇秦': 12039126, '陳近南': 11069727, '華安': 6035999}
# remainPower: 166576174
