# %%
from itertools import combinations


class Glygj(object):
    """
    目的是找出能推進至最多關卡的最佳`門客組合`
    To pass stages as much as possible, we try to find the best `guest combinations` with the minimum waste.
    """
    targets = [200110, 450310, 800680, 1251300, 1801800,
               2452500, 3203900, 4055700, 5008000, 6616990,
               8426000, 11238000, 20000000, 50000000, 100000000, 200000000, 600000000, 700000000]
    guests = {'高漸離': 700000000, '高長恭': 172400000, '魏忠賢': 45363623, '李廣': 42713683,
              '魏徵': 26460423, '干將': 22121455, '蕭劍': 16092176, '陳近南': 11066927,
              '洪承疇': 10070898, '年羹堯': 10065098, '林則徐': 10064098, '李白': 9027434,
              '蘇秦': 9027434, '納蘭明珠': 8032399, '東方朔': 7028349, '華安': 6034599,
              '范文程': 6024299, '張衡': 6024299, '索尼': 6024299, '胡雪巖': 5020149,
              '劉墉': 3009245, '蘇軾': 3009144, '梁紅玉': 2363492, '曹雪芹': 1501888,
              '歐陽修': 1181557, '李衛': 1181462, '紀昀': 1181462, '周培公': 886107,
              '鄭板橋': 590731, '張廷玉': 590727}

    nb_guests = len(guests)
    nb_targets = len(guests)

    def __init__(self):
        self.verbose = False
        self.init_n = 1
        self.breakpoint = 6

    def run(self):
        """
        TODO: Instead of the Brute-force method, ML methods may be more efficient.
        """
        def f1(targetPower):
            scoreboard = []
            for n in range(init_n, len(guests) + 1):
                combs = combinations(guests.keys(), n)
                for comb_names in combs:
                    comb_powers = sum([guests[name] for name in comb_names])
                    waste = comb_powers - targetPower
                    if verbose:
                        print(indents + f"{comb_names}, {comb_powers}, {waste}")
                    if waste >= 0:
                        scoreboard.append((comb_names, comb_powers, waste))
                if n >= breakpoint:
                    break

            if not scoreboard:
                return None

            # check scoreboard
            comb = min(scoreboard, key=lambda x: x[2])
            return comb

        init_n = self.init_n
        guests = self.guests
        targets = self.targets
        breakpoint = self.breakpoint
        verbose = self.verbose

        for targetPower in targets:
            if len(guests) == 0:
                print('done')
                break
            print(f"targetPower: {targetPower}")
            comb = f1(targetPower)
            if comb is None:
                print('done')
                break
            indents = " " * 5
            print(indents + f"lowest_waste: {comb}")
            comb_names = comb[0]
            for comb_name in comb_names:
                guests.pop(comb_name)
            print(indents + f"remain: {len(guests)}")


if __name__ == '__main__':
    g = Glygj()
    g.run()
# Out:
# targetPower: 200110
#      lowest_waste: (('張廷玉',), 590727, 390617)
#      remain: 29
# targetPower: 450310
#      lowest_waste: (('鄭板橋',), 590731, 140421)
#      remain: 28
# targetPower: 800680
#      lowest_waste: (('周培公',), 886107, 85427)
#      remain: 27
# targetPower: 1251300
#      lowest_waste: (('曹雪芹',), 1501888, 250588)
#      remain: 26
# targetPower: 1801800
#      lowest_waste: (('李衛', '紀昀'), 2362924, 561124)
#      remain: 24
# targetPower: 2452500
#      lowest_waste: (('蘇軾',), 3009144, 556644)
#      remain: 23
# targetPower: 3203900
#      lowest_waste: (('梁紅玉', '歐陽修'), 3545049, 341149)
#      remain: 21
# targetPower: 4055700
#      lowest_waste: (('胡雪巖',), 5020149, 964449)
#      remain: 20
# targetPower: 5008000
#      lowest_waste: (('范文程',), 6024299, 1016299)
#      remain: 19
# targetPower: 6616990
#      lowest_waste: (('東方朔',), 7028349, 411359)
#      remain: 18
# targetPower: 8426000
#      lowest_waste: (('李白',), 9027434, 601434)
#      remain: 17
# targetPower: 11238000
#      lowest_waste: (('蘇秦', '劉墉'), 12036679, 798679)
#      remain: 15
# targetPower: 20000000
#      lowest_waste: (('納蘭明珠', '張衡', '索尼'), 20080997, 80997)
#      remain: 12
# targetPower: 50000000
#      lowest_waste: (('魏忠賢', '華安'), 51398222, 1398222)
#      remain: 10
# targetPower: 100000000
#      lowest_waste: (('李廣', '蕭劍', '陳近南', '洪承疇', '年羹堯', '林則徐'), 100072880, 72880)
#      remain: 4
# targetPower: 200000000
#      lowest_waste: (('高長恭', '魏徵', '干將'), 220981878, 20981878)
#      remain: 1
# targetPower: 600000000
#      lowest_waste: (('高漸離',), 700000000, 100000000)
#      remain: 0
# done
